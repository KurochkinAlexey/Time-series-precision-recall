# %%
import numpy as np
import matplotlib as plt
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /root/miniconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
class TSMetric:
    def __init__(self, metric_option="classic", beta=1.0, alpha_r=0.0, cardinality="one", bias_p="flat", bias_r="flat"):
        
        assert (alpha_r >= 0)&(alpha_r <= 1)
        assert metric_option in ["classic", "time-series", "numenta"]
        assert beta > 0
        assert cardinality in ["one", "reciprocal", "udf_gamma"]
        assert bias_p in ["flat", "front", "middle", "back"]
        assert bias_r in ["flat", "front", "middle", "back"]
        
        self.metric_option = metric_option
        self.beta = beta
        self.alpha_r = alpha_r
        self.alpha_p = 0
        self.cardinality = cardinality
        self.bias_p = bias_p
        self.bias_r = bias_r
    
    def _udf_gamma(self, overlap, task_type):
        """
        user defined gamma
        """
        return 1.0
    
    def _gamma_select(self, gamma, overlap, task_type):
        if gamma == "one":
            return 1.0
        elif gamma == "reciprocal":
            if overlap > 1:
                return 1.0/overlap
            else:
                return 1.0
        elif gamma == "udf_gamma_def":
            if overlap > 1:
                return 1.0/self._udf_gamma(overlap, task_type)
            else:
                return 1.0
    
    def _gamma_function(self, overlap_count, task_type):
        overlap = overlap_count[0]
        if task_type == 0:
            return self._gamma_select(self.cardinality, overlap, task_type)
        elif task_type == 1:
            return self._gamma_select(self.cardinality, overlap, task_type)
        else:
            raise Exception("invalid argument in gamma function")
    
    
    def _compute_omega_reward(self, r1, r2, overlap_count, task_type):
        if r1[1] < r2[0] or r1[0] > r2[1]:
            return 0
        else:
            overlap_count[0] += 1
            overlap = np.zeros(r1.shape)
            overlap[0] = max(r1[0], r2[0])
            overlap[1] = min(r1[1], r2[1])
            return self._omega_function(r1, overlap, task_type)
    
    def _omega_function(self, rrange, overlap, task_type):
        anomaly_length = rrange[1] - rrange[0] + 1
        my_positional_bias = 0
        max_positional_bias = 0
        temp_bias = 0
        for i in range(1, anomaly_length+1):
            temp_bias = self._delta_function(i, anomaly_length, task_type)
            max_positional_bias += temp_bias
            j = rrange[0] + i -1
            if j >= overlap[0] and j <= overlap[1]:
                my_positional_bias += temp_bias
        if max_positional_bias > 0:
            res = my_positional_bias / max_positional_bias
            return res
        else:
            return 0
    
    def _delta_function(self, t, anomaly_length, task_type):
        if task_type == 0:
            return self._delta_select(self.bias_p, t, anomaly_length, task_type)
        elif task_type == 1:
            return self._delta_select(self.bias_r, t, anomaly_length, task_type)
        else:
            raise Exception("Invalid task type in delta function")
    
    def _delta_select(self, delta, t, anomaly_length, task_type):
        if delta == "flat":
            return 1.0
        elif delta == "front":
            return float(anomaly_length - t + 1.0)
        elif delta == "middle":
            if t <= anomaly_length/2.0 :
                return float(t)
            else:
                return float(anomaly_length - t + 1.0)
        elif delta == "back":
            return float(t)
        elif delta == "udf_delta":
            return self._udf_delta(t, anomaly_length, task_type)
        else:
            raise Exception("Invalid positional bias value")
    
    def _udf_delta(self, t, anomaly_length, task_type):
        """
        user defined delta function
        """
        return 1.0
    
    def _update_precision(self, real_anomalies, predicted_anomalies):
        precision = 0
        if len(predicted_anomalies) == 0:
            return 0
        for i in range(len(predicted_anomalies)):
            range_p = predicted_anomalies[i, :]
            omega_reward = 0
            overlap_count = [0]
            for j in range(len(real_anomalies)):
                range_r = real_anomalies[j, :]
                omega_reward += self._compute_omega_reward(range_p, range_r, overlap_count, 0)
            overlap_reward = self._gamma_function(overlap_count, 0)*omega_reward
            if overlap_count[0] > 0:
                existence_reward = 1
            else:
                existence_reward = 0

            precision += self.alpha_p*existence_reward + (1 - self.alpha_p)*overlap_reward
        precision /= len(predicted_anomalies)
        return precision
    
    def _update_recall(self, real_anomalies, predicted_anomalies):
        recall = 0
        if len(real_anomalies) == 0:
            return 0
        for i in range(len(real_anomalies)):
            omega_reward = 0
            overlap_count = [0]
            range_r = real_anomalies[i, :]
            for j in range(len(predicted_anomalies)):
                range_p = predicted_anomalies[j, :]
                omega_reward += self._compute_omega_reward(range_r, range_p, overlap_count, 1)
            overlap_reward = self._gamma_function(overlap_count, 1)*omega_reward
            
            if overlap_count[0] > 0:
                existence_reward = 1
            else:
                existence_reward = 0

            recall += self.alpha_r*existence_reward + (1 - self.alpha_r)*overlap_reward
        recall /= len(real_anomalies)
        return recall
    
    def _shift(self, arr, num, fill_value=np.nan):
        arr = np.roll(arr,num)
        if num < 0:
            arr[num:] = fill_value
        elif num > 0:
            arr[:num] = fill_value
        return arr
    
    def _prepare_data(self, values_real, values_pred):
        
        assert len(values_real) == len(values_pred)
        assert np.allclose(np.unique(values_real), np.array([0, 1]))
        assert np.allclose(np.unique(values_pred), np.array([0, 1]))
        
        if self.metric_option == "classic":
            real_anomalies = np.argwhere(values_real == 1).repeat(2, axis=1)
            predicted_anomalies = np.argwhere(values_pred == 1).repeat(2, axis=1)
            
        elif self.metric_option == "time-series":
            predicted_anomalies_ = np.argwhere(values_pred == 1).ravel()
            predicted_anomalies_shift_forward = self._shift(predicted_anomalies_, 1, fill_value=predicted_anomalies_[0])
            predicted_anomalies_shift_backward = self._shift(predicted_anomalies_, -1, fill_value=predicted_anomalies_[-1])
            predicted_anomalies_start = np.argwhere((predicted_anomalies_shift_forward - predicted_anomalies_) != -1).ravel()
            predicted_anomalies_finish = np.argwhere((predicted_anomalies_ - predicted_anomalies_shift_backward) != -1).ravel()
            predicted_anomalies = np.hstack([predicted_anomalies_[predicted_anomalies_start].reshape(-1, 1), \
                                             predicted_anomalies_[predicted_anomalies_finish].reshape(-1, 1)])
            
            real_anomalies_ = np.argwhere(values_real == 1).ravel()
            real_anomalies_shift_forward = self._shift(real_anomalies_, 1, fill_value=real_anomalies_[0])
            real_anomalies_shift_backward = self._shift(real_anomalies_, -1, fill_value=real_anomalies_[-1])
            real_anomalies_start = np.argwhere((real_anomalies_shift_forward - real_anomalies_) != -1).ravel()
            real_anomalies_finish = np.argwhere((real_anomalies_ - real_anomalies_shift_backward) != -1).ravel()
            real_anomalies = np.hstack([real_anomalies_[real_anomalies_start].reshape(-1, 1), \
                                             real_anomalies_[real_anomalies_finish].reshape(-1, 1)])
            
        elif self.metric_option == "numenta":
            predicted_anomalies = np.argwhere(values_pred == 1).repeat(2, axis=1)
            real_anomalies_ = np.argwhere(values_real == 1).ravel()
            real_anomalies_shift_forward = self._shift(real_anomalies_, 1, fill_value=real_anomalies_[0])
            real_anomalies_shift_backward = self._shift(real_anomalies_, -1, fill_value=real_anomalies_[-1])
            real_anomalies_start = np.argwhere((real_anomalies_shift_forward - real_anomalies_) != -1).ravel()
            real_anomalies_finish = np.argwhere((real_anomalies_ - real_anomalies_shift_backward) != -1).ravel()
            real_anomalies = np.hstack([real_anomalies_[real_anomalies_start].reshape(-1, 1), \
                                             real_anomalies_[real_anomalies_finish].reshape(-1, 1)])
        return real_anomalies, predicted_anomalies
    
    def score(self, values_real, values_predicted):
        assert isinstance(values_real, np.ndarray)
        assert isinstance(values_predicted, np.ndarray)
        real_anomalies, predicted_anomalies = self._prepare_data(values_real, values_predicted)
        precision = self._update_precision(real_anomalies, predicted_anomalies)
        recall = self._update_recall(real_anomalies, predicted_anomalies)
        if precision + recall != 0:
            Fbeta = (1 + self.beta**2)*precision*recall/(self.beta**2*precision + recall)
        else:
            Fbeta = 0
        
        return precision, recall, Fbeta

# %% [markdown]
# ### validation

# %%
datasets = ["ecg", "space_shuttle", "sine", "nyc_taxi", "aapl", "machine_temp"]

# %%
for dataset in datasets:
    with open("examples/{}/lstm_ad.real".format(dataset), "r") as f:
        values_real = f.readlines()
    with open("examples/{}/lstm_ad.pred".format(dataset), "r") as f:
        values_pred = f.readlines()
    values_real = np.array([int(value.strip("\n")) for value in values_real])
    values_pred = np.array([int(value.strip("\n")) for value in values_pred])
    plt.figure(figsize=(20, 10))
    plt.title("Dataset {}".format(dataset))
    plt.plot(values_real*1.25)
    plt.plot(values_pred)
    plt.legend(["real anomalies", "predicted anomalies"])
    plt.show()
    
    print("{} metrics: ".format(dataset))
    
    recall_classic = recall_score(values_real, values_pred)
    precision_classic = precision_score(values_real, values_pred)
    f1_classic = f1_score(values_real, values_pred)
    print("classic metric")
    print("precision: ", precision_classic, "recall: ", recall_classic, "f1: ", f1_classic)
    
    classic_metric = TSMetric(metric_option="classic", alpha_r=0.0, cardinality="one", bias_p="flat", bias_r="flat")
    precision_classic_T, recall_classic_T, f1_classic_T = classic_metric.score(values_real, values_pred)
    print("classic metric T")
    print("precision: ", precision_classic_T, "recall: ", recall_classic_T, "f1: ", f1_classic_T)
    
    flat_metric = TSMetric(metric_option="time-series", alpha_r=0.0, cardinality="reciprocal", bias_p="flat", bias_r="flat")
    precision_flat, recall_flat, f1_flat = flat_metric.score(values_real, values_pred)
    print("flat metric")
    print("precision: ", precision_flat, "recall: ", recall_flat, "f1: ", f1_flat)
    
    front_metric = TSMetric(metric_option="time-series", alpha_r=0.0, cardinality="reciprocal", bias_p="flat", bias_r="front")
    precision_front, recall_front, f1_front = front_metric.score(values_real, values_pred)
    print("front metric")
    print("precision: ", precision_front, "recall: ", recall_front, "f1: ", f1_front)
    
    middle_metric = TSMetric(metric_option="time-series", alpha_r=0.0, cardinality="reciprocal", bias_p="flat", bias_r="middle")
    precision_middle, recall_middle, f1_middle = middle_metric.score(values_real, values_pred)
    print("middle metric")
    print("precision: ", precision_middle, "recall: ", recall_middle, "f1: ", f1_middle)
    
    back_metric = TSMetric(metric_option="time-series", alpha_r=0.0, cardinality="reciprocal", bias_p="flat", bias_r="back")
    precision_back, recall_back, f1_back = back_metric.score(values_real, values_pred)
    print("back metric")
    print("precision: ", precision_back, "recall: ", recall_back, "f1: ", f1_back)
    
    fig, ax = plt.subplots(1, 3, figsize=(18, 6))
    plt.subplot(1, 3, 1)
    plt.title("{} recall".format(dataset))
    plt.bar(["recall_classic", "recall_classic_T", "recall_flat", "recall_front", "recall_middle", "recall_back"],
            [recall_classic, recall_classic_T, recall_flat, recall_front, recall_middle, recall_back])
    plt.ylim([0, 1])
    plt.xticks(rotation=45)
    
    plt.subplot(1, 3, 2)
    plt.title("{} precision".format(dataset))
    plt.bar(["precision_classic", "precision_classic_T", "precision_flat"],
            [precision_classic, precision_classic_T, precision_flat])
    plt.ylim([0, 1])
    plt.xticks(rotation=45)
    
    plt.subplot(1, 3, 3)
    plt.title("{} f1".format(dataset))
    plt.bar(["f1_classic", "f1_classic_T", "f1_flat", "f1_front", "f1_middle", "f1_back"],
            [f1_classic, f1_classic_T, f1_flat, f1_front, f1_middle, f1_back])
    plt.ylim([0, 1])
    plt.xticks(rotation=45)
# Out:
# ecg metrics:
# classic metric
# precision:  0.9406830437387658 recall:  0.9257075471698113 f1:  0.9331352154531946
# classic metric T
# precision:  0.9406830437387658 recall:  0.9257075471698113 f1:  0.9331352154531946
# flat metric
# precision:  0.9000071245047777 recall:  0.5564447275432857 f1:  0.687704462702074
# front metric
# precision:  0.9000071245047777 recall:  0.523908005502853 f1:  0.6622879799516269
# middle metric
# precision:  0.9000071245047777 recall:  0.5826897391804456 f1:  0.7073933040294974
# back metric
# precision:  0.9000071245047777 recall:  0.588981449583718 f1:  0.7120101658953265
# space_shuttle metrics:
# classic metric
# precision:  0.7210526315789474 recall:  0.7873563218390804 f1:  0.7527472527472527
# classic metric T
# precision:  0.7210526315789474 recall:  0.7873563218390804 f1:  0.7527472527472527
# flat metric
# precision:  0.5950572876938723 recall:  0.13412686541018323 f1:  0.21891087017760588
# front metric
# ...

# %% [markdown]
# ### test cases

# %% [markdown]
# #### case 1:

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
precision_score(y_true, y_pred), recall_score(y_true, y_pred)
# Out:
# (0.0, 0.0)

# %%
m1 = TSMetric(metric_option="time-series")
m1.score(y_pred, y_true)
# Out:
# (0.0, 0.0, 0)

# %% [markdown]
# #### case 2

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[7] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.5, 0.143, 0.222)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.5, 0.143, 0.222]
# front [0.5, 0.25, 0.333]
# middle [0.5, 0.062, 0.111]
# back [0.5, 0.036, 0.067]

# %% [markdown]
# #### case 3

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[10] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.5, 0.143, 0.222)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.5, 0.143, 0.222]
# front [0.5, 0.143, 0.222]
# middle [0.5, 0.25, 0.333]
# back [0.5, 0.143, 0.222]

# %% [markdown]
# #### case 4

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[13] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.5, 0.143, 0.222)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.5, 0.143, 0.222]
# front [0.5, 0.036, 0.067]
# middle [0.5, 0.062, 0.111]
# back [0.5, 0.25, 0.333]

# %% [markdown]
# #### case 5

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[7] = 1
y_pred[10] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.667, 0.286, 0.4)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.667, 0.286, 0.4]
# front [0.667, 0.393, 0.494]
# middle [0.667, 0.312, 0.426]
# back [0.667, 0.179, 0.282]

# %% [markdown]
# #### case 6

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[10] = 1
y_pred[13] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.667, 0.286, 0.4)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.667, 0.286, 0.4]
# front [0.667, 0.179, 0.282]
# middle [0.667, 0.312, 0.426]
# back [0.667, 0.393, 0.494]

# %% [markdown]
# #### case 7

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[7] = 1
y_pred[13] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.667, 0.286, 0.4)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.667, 0.286, 0.4]
# front [0.667, 0.286, 0.4]
# middle [0.667, 0.125, 0.211]
# back [0.667, 0.286, 0.4]

# %% [markdown]
# #### case 8

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[7] = 1
y_pred[10] = 1
y_pred[13] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.75, 0.429, 0.545)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.75, 0.429, 0.545]
# front [0.75, 0.429, 0.545]
# middle [0.75, 0.375, 0.5]
# back [0.75, 0.429, 0.545]

# %% [markdown]
# #### case 9

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[7] = 1
y_pred[10] = 1
y_pred[13] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.75, 0.429, 0.545)

# %%
for card in ["one", "reciprocal"]:
    m = TSMetric(metric_option="time-series", cardinality=card, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(card, [round(item, 3) for item in sc])
# Out:
# one [0.75, 0.429, 0.545]
# reciprocal [0.75, 0.143, 0.24]

# %% [markdown]
# #### case 10

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[3] = 1
y_pred[10] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.5, 0.143, 0.222)

# %%
for alpha_r in [0.0, 0.25, 0.5, 0.75, 1.0]:
    m = TSMetric(metric_option="time-series", alpha_r=alpha_r)
    sc = m.score(y_true, y_pred)
    print(alpha_r, [round(item, 3) for item in sc])
# Out:
# 0.0 [0.5, 0.143, 0.222]
# 0.25 [0.5, 0.357, 0.417]
# 0.5 [0.5, 0.571, 0.533]
# 0.75 [0.5, 0.786, 0.611]
# 1.0 [0.5, 1.0, 0.667]

# %% [markdown]
# #### case 11

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(0, 7)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.0, 0.0, 0.0)

# %%
m = TSMetric(metric_option="time-series")
sc = m.score(y_true, y_pred)
print([round(item, 3) for item in sc])
# Out:
# [0.0, 0.0, 0]

# %% [markdown]
# #### case 12

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(1, 8)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.143, 0.143, 0.143)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.143, 0.143, 0.143]
# front [0.036, 0.25, 0.062]
# middle [0.062, 0.062, 0.062]
# back [0.25, 0.036, 0.062]

# %% [markdown]
# #### case 13

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(3, 10)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.429, 0.429, 0.429)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.429, 0.429, 0.429]
# front [0.214, 0.643, 0.321]
# middle [0.375, 0.375, 0.375]
# back [0.643, 0.214, 0.321]

# %% [markdown]
# #### case 14

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(7, 14)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (1.0, 1.0, 1.0)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [1.0, 1.0, 1.0]
# front [1.0, 1.0, 1.0]
# middle [1.0, 1.0, 1.0]
# back [1.0, 1.0, 1.0]

# %% [markdown]
# #### case 15

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(10, 17)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.571, 0.571, 0.571)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.571, 0.571, 0.571]
# front [0.786, 0.357, 0.491]
# middle [0.625, 0.625, 0.625]
# back [0.357, 0.786, 0.491]

# %% [markdown]
# #### case 16

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(13, 20)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.143, 0.143, 0.143)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.143, 0.143, 0.143]
# front [0.25, 0.036, 0.062]
# middle [0.062, 0.062, 0.062]
# back [0.036, 0.25, 0.062]

# %% [markdown]
# #### case 17

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(2, 9)] = 1
y_pred[range(12, 19)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.286, 0.571, 0.381)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.286, 0.571, 0.381]
# front [0.286, 0.571, 0.381]
# middle [0.188, 0.375, 0.25]
# back [0.286, 0.571, 0.381]

# %%
for card in ["one", "reciprocal"]:
    m = TSMetric(metric_option="time-series", cardinality=card, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(card, [round(item, 3) for item in sc])
# Out:
# one [0.286, 0.571, 0.381]
# reciprocal [0.286, 0.286, 0.286]

# %% [markdown]
# #### case 18

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(5, 16)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.636, 1.0, 0.778)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.636, 1.0, 0.778]
# front [0.636, 1.0, 0.778]
# middle [0.833, 1.0, 0.909]
# back [0.636, 1.0, 0.778]

# %% [markdown]
# #### case 19

# %%
y_true = np.zeros(20)
y_true[range(7, 14)] = 1
y_pred = np.zeros(20)
y_pred[range(2, 16)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.5, 1.0, 0.667)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.5, 1.0, 0.667]
# front [0.4, 1.0, 0.571]
# middle [0.679, 1.0, 0.809]
# back [0.6, 1.0, 0.75]

# %% [markdown]
# #### case 20

# %%
y_true = np.zeros(20)
y_true[range(3, 7)] = 1
y_true[range(11, 15)] = 1
y_pred = np.zeros(20)
y_pred[range(5, 13)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.5, 0.5, 0.5)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.5, 0.5, 0.5]
# front [0.5, 0.5, 0.5]
# middle [0.3, 0.5, 0.375]
# back [0.5, 0.5, 0.5]

# %%
for card in ["one", "reciprocal"]:
    m = TSMetric(metric_option="time-series", cardinality=card, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(card, [round(item, 3) for item in sc])
# Out:
# one [0.5, 0.5, 0.5]
# reciprocal [0.25, 0.5, 0.333]

# %% [markdown]
# #### case 21

# %%
y_true = np.zeros(20)
y_true[range(3, 7)] = 1
y_true[range(11, 15)] = 1
y_pred = np.zeros(20)
y_pred[range(2, 16)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.571, 1.0, 0.727)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.571, 1.0, 0.727]
# front [0.571, 1.0, 0.727]
# middle [0.5, 1.0, 0.667]
# back [0.571, 1.0, 0.727]

# %%
for card in ["one", "reciprocal"]:
    m = TSMetric(metric_option="time-series", cardinality=card, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(card, [round(item, 3) for item in sc])
# Out:
# one [0.571, 1.0, 0.727]
# reciprocal [0.286, 1.0, 0.444]

# %% [markdown]
# #### case 22

# %%
y_true = np.zeros(20)
y_true[range(3, 7)] = 1
y_true[range(11, 15)] = 1
y_pred = np.zeros(20)
y_pred[range(2, 12)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.5, 0.625, 0.556)

# %%
for bias in ["flat", "front", "middle", "back"]:
    m = TSMetric(metric_option="time-series", bias_r=bias, bias_p=bias, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(bias, [round(item, 3) for item in sc])
# Out:
# flat [0.5, 0.625, 0.556]
# front [0.564, 0.7, 0.624]
# middle [0.5, 0.583, 0.538]
# back [0.436, 0.55, 0.487]

# %%
for card in ["one", "reciprocal"]:
    m = TSMetric(metric_option="time-series", cardinality=card, alpha_r=0.0)
    sc = m.score(y_true, y_pred)
    print(card, [round(item, 3) for item in sc])
# Out:
# one [0.5, 0.625, 0.556]
# reciprocal [0.25, 0.625, 0.357]

# %% [markdown]
# #### case 23

# %%
y_true = np.zeros(20)
y_true[range(3, 17)] = 1
y_pred = np.zeros(20)
y_pred[range(4, 8)] = 1
y_pred[range(14, 19)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.778, 0.5, 0.609)

# %%
m = TSMetric(metric_option="time-series")
sc = m.score(y_true, y_pred)
print([round(item, 3) for item in sc])
# Out:
# [0.8, 0.5, 0.615]

# %% [markdown]
# #### case 24

# %%
y_true = np.zeros(20)
y_true[range(3, 8)] = 1
y_true[range(12, 19)] = 1
y_pred = np.zeros(20)
y_pred[range(4, 9)] = 1
plt.plot(figsize=(20, 10))
plt.plot(y_true)
plt.plot(y_pred)

# %%
round(precision_score(y_true, y_pred), 3), round(recall_score(y_true, y_pred), 3), round(f1_score(y_true, y_pred), 3)
# Out:
# (0.8, 0.333, 0.471)

# %%
m = TSMetric(metric_option="time-series")
sc = m.score(y_true, y_pred)
print([round(item, 3) for item in sc])
# Out:
# [0.8, 0.4, 0.533]
